# %% [markdown]
# # OKD-NOKD Dataset and Pose Detection Use-Case
# ---
# ### Exploring the classification of catcher positioning (one-knee down vs. both knees down) by utilizing the pose of the catcher for datapoints with a classification model.

# %% [markdown]
# ## Data Prep from Pose Points for OKD/NOKD Classification
#
# - Load dataset OKD_NOKD
# - Apply YOLO pose detection (using large v8 model) for keypoints
# - Create dataframe for analysis

# %%
import cv2
import os
import pandas as pd
from ultralytics import YOLO
from scripts.load_tools import load_dataset


pose_model = YOLO("yolov8l-pose.pt")

load_dataset("datasets/yolo/OKD_NOKD.txt")

# input folder with OKD and NOKD classification folders
input_folder = "OKD_NOKD/data/"

# Create empty pose data list
pose_data = []

# columns for df
columns = ['filename', 'OKD', 'NOKD']
for i in range(17):  # Assuming 17 keypoints
    columns.extend([f'pose_x_{i}', f'pose_y_{i}'])

# Process each subfolder
for subfolder in ['OKD', 'NOKD']:
    subfolder_path = os.path.join(input_folder, subfolder)

    for filename in os.listdir(subfolder_path):
        if filename.lower().endswith(('.jpg', '.jpeg')):
            input_path = os.path.join(subfolder_path, filename)

            img = cv2.imread(input_path)
            if img is None:
                print(f"{input_path} failed to load.")
                continue

            # run pose with 10% confidence min threshold
            pose_results = pose_model(img, device='mps', verbose=False, conf=0.1)[0]
            pose_points = pose_results.keypoints[0].xyn[0].cpu().numpy().tolist()
            pose_points = [(float(x), float(y)) for x, y in pose_points]

            # Determine OKD or NOKD based on classification folder
            okd = 1 if subfolder == 'OKD' else 0
            nokd = 1 - okd

            row = [filename, okd, nokd]
            
            for i in range(17):
                if i < len(pose_points):
                    row.extend(pose_points[i])
                else:
                    row.extend([None, None])  # None if missing

            pose_data.append(row)

df = pd.DataFrame(pose_data, columns=columns)
print(f"Rows: {df.shape[0]} | Columns: {df.shape[1]}")
df.head()
# Out:
# Downloading Dataset: 100%|██████████| 113M/113M [00:07<00:00, 14.6MiB/s]
# Dataset downloaded and extracted to OKD_NOKD.
# WARNING ⚠️ Apple MPS known Pose bug. Recommend 'device=cpu' for Pose models. See https://github.com/ultralytics/ultralytics/issues/4031.
# Rows: 2816 | Columns: 37
#      filename  OKD  NOKD  pose_x_0  pose_y_0  pose_x_1  pose_y_1  pose_x_2  \
# 0  003301.jpg    1     0  0.790011  0.153460  0.802203  0.139449  0.784699
# 1  000608.jpg    1     0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  001270.jpg    1     0  0.721860  0.119212  0.731224  0.102129  0.000000
# 3  005002.jpg    1     0  0.402278  0.342783  0.418348  0.332589  0.397017
# 4  003473.jpg    1     0  0.810342  0.037531  0.824416  0.018822  0.795775
#
#    pose_y_2  pose_x_3  ...  pose_x_12  pose_y_12  pose_x_13  pose_y_13  \
# 0  0.137306  0.833918  ...   0.958046   0.394738   0.821571   0.580520
# 1  0.000000  0.723342  ...   0.882876   0.382014   0.821561   0.536551
# 2  0.000000  0.772603  ...   0.848121   0.374772   0.845932   0.504056
# 3  0.330485  0.444214  ...   0.409693   0.593397   0.627751   0.542191
# 4  0.027020  0.866920  ...   0.905130   0.312765   0.885468   0.516388
#
#    pose_x_14  pose_y_14  pose_x_15  pose_y_15  pose_x_16  pose_y_16
# 0   0.844192   0.546921   0.926096   0.731617   0.905766   0.720922
# 1   0.832790   0.516380   0.849846   0.721451   0.884939   0.651804
# 2   0.789903   0.536188   0.882470   0.693847   0.799509   0.663481
# 3   0.290840   0.633584   0.713278   0.650721   0.440318   0.643927
# 4   0.838246   0.506505   0.955514   0.730053   0.896856   0.700632
#
# [5 rows x 37 columns]

# %% [markdown]
# ### Fill NaN values with 0, print value counts for OKD (should be even-split with 1408 of each class)

# %%
df.fillna(0, inplace=True)
df[['OKD']].value_counts()
# Out:
# OKD
# 0      1408
# 1      1408
# Name: count, dtype: int64

# %% [markdown]
# ## Train AutoML Classification Instance
#
# ### Explore different types of sci-kit learn models to find the best model for this specific use-case
#
# - Create an 80/20 train/test split based on feature points and target OKD
# - Train AutoML classifier for 6 minutes optimizing for accuracy
# - Print Accuracy and Classification Report

# %%
from flaml import AutoML
from sklearn.model_selection import train_test_split
from sklearn.exceptions import ConvergenceWarning
from sklearn.metrics import accuracy_score, classification_report
import warnings

warnings.filterwarnings('ignore', category=ConvergenceWarning) #ignore warnings about iterations of non-converging models

features = df.drop(columns=['filename', 'OKD', 'NOKD']) #keypoint data
target = df['OKD'] #train to predict OKD

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=22, stratify=target, shuffle=True) #80/20 train/test split

model = AutoML() 

model.fit(X_train, y_train, task='classification', metric='accuracy', time_budget=360) #train classifier for 6 minutes optimizing for accuracy


print(f"Estimator: {model.best_estimator}")
print(f"Config: {model.best_config}")

y_test_predict = model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_predict)

print(f"Test Accuracy: {test_accuracy:.3f}")
print(f"Classification: {classification_report(y_test, y_test_predict)}")
# Out:
# [flaml.automl.logger: 09-27 14:48:04] {1680} INFO - task = classification
# [flaml.automl.logger: 09-27 14:48:04] {1691} INFO - Evaluation method: cv
# [flaml.automl.logger: 09-27 14:48:04] {1789} INFO - Minimizing error metric: 1-accuracy
# [flaml.automl.logger: 09-27 14:48:04] {1901} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'lrl1']
# [flaml.automl.logger: 09-27 14:48:04] {2219} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:04] {2345} INFO - Estimated sufficient time budget=503s. Estimated necessary time budget=12s.
# [flaml.automl.logger: 09-27 14:48:04] {2392} INFO -  at 0.1s,	estimator lgbm's best error=0.3148,	best estimator lgbm's best error=0.3148
# [flaml.automl.logger: 09-27 14:48:04] {2219} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:04] {2392} INFO -  at 0.1s,	estimator lgbm's best error=0.3131,	best estimator lgbm's best error=0.3131
# [flaml.automl.logger: 09-27 14:48:04] {2219} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:04] {2392} INFO -  at 0.2s,	estimator lgbm's best error=0.3131,	best estimator lgbm's best error=0.3131
# [flaml.automl.logger: 09-27 14:48:04] {2219} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:04] {2392} INFO -  at 0.2s,	estimator lgbm's best error=0.3108,	best estimator lgbm's best error=0.3108
# [flaml.automl.logger: 09-27 14:48:04] {2219} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:04] {2392} INFO -  at 0.2s,	estimator lgbm's best error=0.3108,	best estimator lgbm's best error=0.3108
# [flaml.automl.logger: 09-27 14:48:04] {2219} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:04] {2392} INFO -  at 0.3s,	estimator lgbm's best error=0.2758,	best estimator lgbm's best error=0.2758
# [flaml.automl.logger: 09-27 14:48:04] {2219} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:04] {2392} INFO -  at 0.3s,	estimator lgbm's best error=0.2758,	best estimator lgbm's best error=0.2758
# [flaml.automl.logger: 09-27 14:48:04] {2219} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:04] {2392} INFO -  at 0.4s,	estimator lgbm's best error=0.2664,	best estimator lgbm's best error=0.2664
# [flaml.automl.logger: 09-27 14:48:04] {2219} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:04] {2392} INFO -  at 0.4s,	estimator lgbm's best error=0.2664,	best estimator lgbm's best error=0.2664
# [flaml.automl.logger: 09-27 14:48:04] {2219} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:04] {2392} INFO -  at 0.4s,	estimator lgbm's best error=0.2664,	best estimator lgbm's best error=0.2664
# [flaml.automl.logger: 09-27 14:48:04] {2219} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:05] {2392} INFO -  at 0.5s,	estimator lgbm's best error=0.2433,	best estimator lgbm's best error=0.2433
# [flaml.automl.logger: 09-27 14:48:05] {2219} INFO - iteration 11, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:05] {2392} INFO -  at 0.6s,	estimator xgboost's best error=0.3139,	best estimator lgbm's best error=0.2433
# [flaml.automl.logger: 09-27 14:48:05] {2219} INFO - iteration 12, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:05] {2392} INFO -  at 0.6s,	estimator xgboost's best error=0.3108,	best estimator lgbm's best error=0.2433
# [flaml.automl.logger: 09-27 14:48:05] {2219} INFO - iteration 13, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:05] {2392} INFO -  at 0.8s,	estimator extra_tree's best error=0.4063,	best estimator lgbm's best error=0.2433
# [flaml.automl.logger: 09-27 14:48:05] {2219} INFO - iteration 14, current learner rf
# [flaml.automl.logger: 09-27 14:48:05] {2392} INFO -  at 1.0s,	estimator rf's best error=0.3388,	best estimator lgbm's best error=0.2433
# [flaml.automl.logger: 09-27 14:48:05] {2219} INFO - iteration 15, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:05] {2392} INFO -  at 1.0s,	estimator xgboost's best error=0.3108,	best estimator lgbm's best error=0.2433
# [flaml.automl.logger: 09-27 14:48:05] {2219} INFO - iteration 16, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:05] {2392} INFO -  at 1.1s,	estimator lgbm's best error=0.2358,	best estimator lgbm's best error=0.2358
# [flaml.automl.logger: 09-27 14:48:05] {2219} INFO - iteration 17, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:05] {2392} INFO -  at 1.3s,	estimator extra_tree's best error=0.3632,	best estimator lgbm's best error=0.2358
# [flaml.automl.logger: 09-27 14:48:05] {2219} INFO - iteration 18, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:05] {2392} INFO -  at 1.4s,	estimator lgbm's best error=0.2358,	best estimator lgbm's best error=0.2358
# [flaml.automl.logger: 09-27 14:48:05] {2219} INFO - iteration 19, current learner rf
# [flaml.automl.logger: 09-27 14:48:06] {2392} INFO -  at 1.5s,	estimator rf's best error=0.2789,	best estimator lgbm's best error=0.2358
# [flaml.automl.logger: 09-27 14:48:06] {2219} INFO - iteration 20, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:06] {2392} INFO -  at 1.7s,	estimator lgbm's best error=0.2358,	best estimator lgbm's best error=0.2358
# [flaml.automl.logger: 09-27 14:48:06] {2219} INFO - iteration 21, current learner rf
# [flaml.automl.logger: 09-27 14:48:06] {2392} INFO -  at 1.8s,	estimator rf's best error=0.2789,	best estimator lgbm's best error=0.2358
# [flaml.automl.logger: 09-27 14:48:06] {2219} INFO - iteration 22, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:06] {2392} INFO -  at 2.0s,	estimator lgbm's best error=0.2358,	best estimator lgbm's best error=0.2358
# [flaml.automl.logger: 09-27 14:48:06] {2219} INFO - iteration 23, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:06] {2392} INFO -  at 2.2s,	estimator lgbm's best error=0.2358,	best estimator lgbm's best error=0.2358
# [flaml.automl.logger: 09-27 14:48:06] {2219} INFO - iteration 24, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:06] {2392} INFO -  at 2.3s,	estimator xgboost's best error=0.2997,	best estimator lgbm's best error=0.2358
# [flaml.automl.logger: 09-27 14:48:06] {2219} INFO - iteration 25, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:06] {2392} INFO -  at 2.4s,	estimator extra_tree's best error=0.3632,	best estimator lgbm's best error=0.2358
# [flaml.automl.logger: 09-27 14:48:06] {2219} INFO - iteration 26, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:07] {2392} INFO -  at 2.6s,	estimator lgbm's best error=0.2358,	best estimator lgbm's best error=0.2358
# [flaml.automl.logger: 09-27 14:48:07] {2219} INFO - iteration 27, current learner rf
# [flaml.automl.logger: 09-27 14:48:07] {2392} INFO -  at 2.7s,	estimator rf's best error=0.2789,	best estimator lgbm's best error=0.2358
# [flaml.automl.logger: 09-27 14:48:07] {2219} INFO - iteration 28, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:07] {2392} INFO -  at 2.9s,	estimator extra_tree's best error=0.3632,	best estimator lgbm's best error=0.2358
# [flaml.automl.logger: 09-27 14:48:07] {2219} INFO - iteration 29, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:07] {2392} INFO -  at 3.0s,	estimator xgboost's best error=0.2784,	best estimator lgbm's best error=0.2358
# [flaml.automl.logger: 09-27 14:48:07] {2219} INFO - iteration 30, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:07] {2392} INFO -  at 3.1s,	estimator lgbm's best error=0.2345,	best estimator lgbm's best error=0.2345
# [flaml.automl.logger: 09-27 14:48:07] {2219} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:07] {2392} INFO -  at 3.2s,	estimator lgbm's best error=0.2345,	best estimator lgbm's best error=0.2345
# [flaml.automl.logger: 09-27 14:48:07] {2219} INFO - iteration 32, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:07] {2392} INFO -  at 3.4s,	estimator lgbm's best error=0.2269,	best estimator lgbm's best error=0.2269
# [flaml.automl.logger: 09-27 14:48:07] {2219} INFO - iteration 33, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:07] {2392} INFO -  at 3.5s,	estimator xgboost's best error=0.2780,	best estimator lgbm's best error=0.2269
# [flaml.automl.logger: 09-27 14:48:07] {2219} INFO - iteration 34, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:08] {2392} INFO -  at 4.0s,	estimator lgbm's best error=0.2269,	best estimator lgbm's best error=0.2269
# [flaml.automl.logger: 09-27 14:48:08] {2219} INFO - iteration 35, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:08] {2392} INFO -  at 4.0s,	estimator lgbm's best error=0.2269,	best estimator lgbm's best error=0.2269
# [flaml.automl.logger: 09-27 14:48:08] {2219} INFO - iteration 36, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:08] {2392} INFO -  at 4.2s,	estimator extra_tree's best error=0.3397,	best estimator lgbm's best error=0.2269
# [flaml.automl.logger: 09-27 14:48:08] {2219} INFO - iteration 37, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:08] {2392} INFO -  at 4.3s,	estimator lgbm's best error=0.2269,	best estimator lgbm's best error=0.2269
# [flaml.automl.logger: 09-27 14:48:08] {2219} INFO - iteration 38, current learner rf
# [flaml.automl.logger: 09-27 14:48:08] {2392} INFO -  at 4.4s,	estimator rf's best error=0.2789,	best estimator lgbm's best error=0.2269
# [flaml.automl.logger: 09-27 14:48:08] {2219} INFO - iteration 39, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:09] {2392} INFO -  at 4.5s,	estimator lgbm's best error=0.2269,	best estimator lgbm's best error=0.2269
# [flaml.automl.logger: 09-27 14:48:09] {2219} INFO - iteration 40, current learner rf
# [flaml.automl.logger: 09-27 14:48:09] {2392} INFO -  at 4.7s,	estimator rf's best error=0.2789,	best estimator lgbm's best error=0.2269
# [flaml.automl.logger: 09-27 14:48:09] {2219} INFO - iteration 41, current learner rf
# [flaml.automl.logger: 09-27 14:48:09] {2392} INFO -  at 4.9s,	estimator rf's best error=0.2713,	best estimator lgbm's best error=0.2269
# [flaml.automl.logger: 09-27 14:48:09] {2219} INFO - iteration 42, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:09] {2392} INFO -  at 5.2s,	estimator lgbm's best error=0.2269,	best estimator lgbm's best error=0.2269
# [flaml.automl.logger: 09-27 14:48:09] {2219} INFO - iteration 43, current learner rf
# [flaml.automl.logger: 09-27 14:48:09] {2392} INFO -  at 5.4s,	estimator rf's best error=0.2624,	best estimator lgbm's best error=0.2269
# [flaml.automl.logger: 09-27 14:48:09] {2219} INFO - iteration 44, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:10] {2392} INFO -  at 5.6s,	estimator extra_tree's best error=0.3397,	best estimator lgbm's best error=0.2269
# [flaml.automl.logger: 09-27 14:48:10] {2219} INFO - iteration 45, current learner rf
# [flaml.automl.logger: 09-27 14:48:10] {2392} INFO -  at 5.7s,	estimator rf's best error=0.2624,	best estimator lgbm's best error=0.2269
# [flaml.automl.logger: 09-27 14:48:10] {2219} INFO - iteration 46, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:10] {2392} INFO -  at 5.8s,	estimator lgbm's best error=0.2269,	best estimator lgbm's best error=0.2269
# [flaml.automl.logger: 09-27 14:48:10] {2219} INFO - iteration 47, current learner rf
# [flaml.automl.logger: 09-27 14:48:10] {2392} INFO -  at 6.0s,	estimator rf's best error=0.2624,	best estimator lgbm's best error=0.2269
# [flaml.automl.logger: 09-27 14:48:10] {2219} INFO - iteration 48, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:10] {2392} INFO -  at 6.1s,	estimator lgbm's best error=0.2149,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:10] {2219} INFO - iteration 49, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:10] {2392} INFO -  at 6.2s,	estimator lgbm's best error=0.2149,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:10] {2219} INFO - iteration 50, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:10] {2392} INFO -  at 6.4s,	estimator extra_tree's best error=0.3219,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:10] {2219} INFO - iteration 51, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:10] {2392} INFO -  at 6.4s,	estimator lgbm's best error=0.2149,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:10] {2219} INFO - iteration 52, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:11] {2392} INFO -  at 6.8s,	estimator lgbm's best error=0.2149,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:11] {2219} INFO - iteration 53, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:11] {2392} INFO -  at 6.9s,	estimator lgbm's best error=0.2149,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:11] {2219} INFO - iteration 54, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:11] {2392} INFO -  at 7.1s,	estimator lgbm's best error=0.2149,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:11] {2219} INFO - iteration 55, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:11] {2392} INFO -  at 7.3s,	estimator lgbm's best error=0.2149,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:11] {2219} INFO - iteration 56, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:11] {2392} INFO -  at 7.4s,	estimator lgbm's best error=0.2149,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:11] {2219} INFO - iteration 57, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:12] {2392} INFO -  at 8.0s,	estimator lgbm's best error=0.2149,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:12] {2219} INFO - iteration 58, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:12] {2392} INFO -  at 8.1s,	estimator lgbm's best error=0.2149,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:12] {2219} INFO - iteration 59, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:12] {2392} INFO -  at 8.4s,	estimator lgbm's best error=0.2149,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:12] {2219} INFO - iteration 60, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:12] {2392} INFO -  at 8.5s,	estimator lgbm's best error=0.2149,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:12] {2219} INFO - iteration 61, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:13] {2392} INFO -  at 9.1s,	estimator lgbm's best error=0.2149,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:13] {2219} INFO - iteration 62, current learner rf
# [flaml.automl.logger: 09-27 14:48:13] {2392} INFO -  at 9.3s,	estimator rf's best error=0.2447,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:13] {2219} INFO - iteration 63, current learner rf
# [flaml.automl.logger: 09-27 14:48:14] {2392} INFO -  at 9.5s,	estimator rf's best error=0.2447,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:14] {2219} INFO - iteration 64, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:14] {2392} INFO -  at 9.6s,	estimator lgbm's best error=0.2149,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:14] {2219} INFO - iteration 65, current learner rf
# [flaml.automl.logger: 09-27 14:48:14] {2392} INFO -  at 9.8s,	estimator rf's best error=0.2371,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:14] {2219} INFO - iteration 66, current learner rf
# [flaml.automl.logger: 09-27 14:48:14] {2392} INFO -  at 10.0s,	estimator rf's best error=0.2371,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:14] {2219} INFO - iteration 67, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:14] {2392} INFO -  at 10.1s,	estimator lgbm's best error=0.2149,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:14] {2219} INFO - iteration 68, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:15] {2392} INFO -  at 10.7s,	estimator lgbm's best error=0.2149,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:15] {2219} INFO - iteration 69, current learner rf
# [flaml.automl.logger: 09-27 14:48:15] {2392} INFO -  at 11.1s,	estimator rf's best error=0.2282,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:15] {2219} INFO - iteration 70, current learner rf
# [flaml.automl.logger: 09-27 14:48:15] {2392} INFO -  at 11.3s,	estimator rf's best error=0.2242,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:15] {2219} INFO - iteration 71, current learner rf
# [flaml.automl.logger: 09-27 14:48:16] {2392} INFO -  at 11.7s,	estimator rf's best error=0.2242,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:16] {2219} INFO - iteration 72, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:16] {2392} INFO -  at 11.8s,	estimator extra_tree's best error=0.2775,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:16] {2219} INFO - iteration 73, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:16] {2392} INFO -  at 12.0s,	estimator extra_tree's best error=0.2775,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:16] {2219} INFO - iteration 74, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:16] {2392} INFO -  at 12.2s,	estimator extra_tree's best error=0.2775,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:16] {2219} INFO - iteration 75, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:17] {2392} INFO -  at 12.6s,	estimator lgbm's best error=0.2149,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:17] {2219} INFO - iteration 76, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:17] {2392} INFO -  at 12.7s,	estimator lgbm's best error=0.2149,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:17] {2219} INFO - iteration 77, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:17] {2392} INFO -  at 12.9s,	estimator extra_tree's best error=0.2642,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:17] {2219} INFO - iteration 78, current learner rf
# [flaml.automl.logger: 09-27 14:48:17] {2392} INFO -  at 13.1s,	estimator rf's best error=0.2242,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:17] {2219} INFO - iteration 79, current learner xgb_limitdepth
# [flaml.automl.logger: 09-27 14:48:17] {2392} INFO -  at 13.3s,	estimator xgb_limitdepth's best error=0.2327,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:17] {2219} INFO - iteration 80, current learner xgb_limitdepth
# [flaml.automl.logger: 09-27 14:48:17] {2392} INFO -  at 13.4s,	estimator xgb_limitdepth's best error=0.2327,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:17] {2219} INFO - iteration 81, current learner xgb_limitdepth
# [flaml.automl.logger: 09-27 14:48:18] {2392} INFO -  at 13.5s,	estimator xgb_limitdepth's best error=0.2327,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:18] {2219} INFO - iteration 82, current learner xgb_limitdepth
# [flaml.automl.logger: 09-27 14:48:18] {2392} INFO -  at 13.6s,	estimator xgb_limitdepth's best error=0.2327,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:18] {2219} INFO - iteration 83, current learner xgb_limitdepth
# [flaml.automl.logger: 09-27 14:48:18] {2392} INFO -  at 13.8s,	estimator xgb_limitdepth's best error=0.2327,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:18] {2219} INFO - iteration 84, current learner xgb_limitdepth
# [flaml.automl.logger: 09-27 14:48:18] {2392} INFO -  at 13.9s,	estimator xgb_limitdepth's best error=0.2327,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:18] {2219} INFO - iteration 85, current learner xgb_limitdepth
# [flaml.automl.logger: 09-27 14:48:18] {2392} INFO -  at 14.0s,	estimator xgb_limitdepth's best error=0.2322,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:18] {2219} INFO - iteration 86, current learner rf
# [flaml.automl.logger: 09-27 14:48:18] {2392} INFO -  at 14.5s,	estimator rf's best error=0.2225,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:18] {2219} INFO - iteration 87, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:19] {2392} INFO -  at 14.7s,	estimator extra_tree's best error=0.2642,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:19] {2219} INFO - iteration 88, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:19] {2392} INFO -  at 14.7s,	estimator lgbm's best error=0.2149,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:19] {2219} INFO - iteration 89, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:20] {2392} INFO -  at 15.7s,	estimator lgbm's best error=0.2149,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:20] {2219} INFO - iteration 90, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:20] {2392} INFO -  at 15.9s,	estimator extra_tree's best error=0.2491,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:20] {2219} INFO - iteration 91, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:20] {2392} INFO -  at 16.1s,	estimator extra_tree's best error=0.2491,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:20] {2219} INFO - iteration 92, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:20] {2392} INFO -  at 16.3s,	estimator extra_tree's best error=0.2491,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:20] {2219} INFO - iteration 93, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:21] {2392} INFO -  at 16.6s,	estimator extra_tree's best error=0.2424,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:21] {2219} INFO - iteration 94, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:21] {2392} INFO -  at 16.6s,	estimator xgboost's best error=0.2749,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:21] {2219} INFO - iteration 95, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:21] {2392} INFO -  at 16.7s,	estimator lgbm's best error=0.2149,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:21] {2219} INFO - iteration 96, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:21] {2392} INFO -  at 16.9s,	estimator extra_tree's best error=0.2424,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:21] {2219} INFO - iteration 97, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:21] {2392} INFO -  at 17.0s,	estimator xgboost's best error=0.2726,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:21] {2219} INFO - iteration 98, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:21] {2392} INFO -  at 17.0s,	estimator xgboost's best error=0.2726,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:21] {2219} INFO - iteration 99, current learner rf
# [flaml.automl.logger: 09-27 14:48:22] {2392} INFO -  at 17.6s,	estimator rf's best error=0.2202,	best estimator lgbm's best error=0.2149
# [flaml.automl.logger: 09-27 14:48:22] {2219} INFO - iteration 100, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:23] {2392} INFO -  at 18.7s,	estimator lgbm's best error=0.2136,	best estimator lgbm's best error=0.2136
# [flaml.automl.logger: 09-27 14:48:23] {2219} INFO - iteration 101, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:23] {2392} INFO -  at 18.8s,	estimator extra_tree's best error=0.2424,	best estimator lgbm's best error=0.2136
# [flaml.automl.logger: 09-27 14:48:23] {2219} INFO - iteration 102, current learner rf
# [flaml.automl.logger: 09-27 14:48:23] {2392} INFO -  at 19.2s,	estimator rf's best error=0.2202,	best estimator lgbm's best error=0.2136
# [flaml.automl.logger: 09-27 14:48:23] {2219} INFO - iteration 103, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:23] {2392} INFO -  at 19.4s,	estimator lgbm's best error=0.2136,	best estimator lgbm's best error=0.2136
# [flaml.automl.logger: 09-27 14:48:23] {2219} INFO - iteration 104, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:23] {2392} INFO -  at 19.5s,	estimator xgboost's best error=0.2567,	best estimator lgbm's best error=0.2136
# [flaml.automl.logger: 09-27 14:48:23] {2219} INFO - iteration 105, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:24] {2392} INFO -  at 19.5s,	estimator xgboost's best error=0.2567,	best estimator lgbm's best error=0.2136
# [flaml.automl.logger: 09-27 14:48:24] {2219} INFO - iteration 106, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:24] {2392} INFO -  at 19.6s,	estimator xgboost's best error=0.2567,	best estimator lgbm's best error=0.2136
# [flaml.automl.logger: 09-27 14:48:24] {2219} INFO - iteration 107, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:24] {2392} INFO -  at 19.7s,	estimator xgboost's best error=0.2567,	best estimator lgbm's best error=0.2136
# [flaml.automl.logger: 09-27 14:48:24] {2219} INFO - iteration 108, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:24] {2392} INFO -  at 19.8s,	estimator xgboost's best error=0.2513,	best estimator lgbm's best error=0.2136
# [flaml.automl.logger: 09-27 14:48:24] {2219} INFO - iteration 109, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:24] {2392} INFO -  at 19.9s,	estimator extra_tree's best error=0.2345,	best estimator lgbm's best error=0.2136
# [flaml.automl.logger: 09-27 14:48:24] {2219} INFO - iteration 110, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:24] {2392} INFO -  at 20.0s,	estimator xgboost's best error=0.2513,	best estimator lgbm's best error=0.2136
# [flaml.automl.logger: 09-27 14:48:24] {2219} INFO - iteration 111, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:27] {2392} INFO -  at 23.3s,	estimator lgbm's best error=0.2136,	best estimator lgbm's best error=0.2136
# [flaml.automl.logger: 09-27 14:48:27] {2219} INFO - iteration 112, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:28] {2392} INFO -  at 23.5s,	estimator extra_tree's best error=0.2118,	best estimator extra_tree's best error=0.2118
# [flaml.automl.logger: 09-27 14:48:28] {2219} INFO - iteration 113, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:28] {2392} INFO -  at 23.7s,	estimator extra_tree's best error=0.2118,	best estimator extra_tree's best error=0.2118
# [flaml.automl.logger: 09-27 14:48:28] {2219} INFO - iteration 114, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:28] {2392} INFO -  at 23.9s,	estimator extra_tree's best error=0.2118,	best estimator extra_tree's best error=0.2118
# [flaml.automl.logger: 09-27 14:48:28] {2219} INFO - iteration 115, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:28] {2392} INFO -  at 24.1s,	estimator extra_tree's best error=0.2118,	best estimator extra_tree's best error=0.2118
# [flaml.automl.logger: 09-27 14:48:28] {2219} INFO - iteration 116, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:28] {2392} INFO -  at 24.1s,	estimator xgboost's best error=0.2513,	best estimator extra_tree's best error=0.2118
# [flaml.automl.logger: 09-27 14:48:28] {2219} INFO - iteration 117, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:28] {2392} INFO -  at 24.4s,	estimator extra_tree's best error=0.2118,	best estimator extra_tree's best error=0.2118
# [flaml.automl.logger: 09-27 14:48:28] {2219} INFO - iteration 118, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:29] {2392} INFO -  at 24.6s,	estimator extra_tree's best error=0.2118,	best estimator extra_tree's best error=0.2118
# [flaml.automl.logger: 09-27 14:48:29] {2219} INFO - iteration 119, current learner rf
# [flaml.automl.logger: 09-27 14:48:29] {2392} INFO -  at 25.2s,	estimator rf's best error=0.2202,	best estimator extra_tree's best error=0.2118
# [flaml.automl.logger: 09-27 14:48:29] {2219} INFO - iteration 120, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:29] {2392} INFO -  at 25.4s,	estimator extra_tree's best error=0.2118,	best estimator extra_tree's best error=0.2118
# [flaml.automl.logger: 09-27 14:48:29] {2219} INFO - iteration 121, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:30] {2392} INFO -  at 25.5s,	estimator extra_tree's best error=0.2118,	best estimator extra_tree's best error=0.2118
# [flaml.automl.logger: 09-27 14:48:30] {2219} INFO - iteration 122, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:30] {2392} INFO -  at 25.8s,	estimator extra_tree's best error=0.2118,	best estimator extra_tree's best error=0.2118
# [flaml.automl.logger: 09-27 14:48:30] {2219} INFO - iteration 123, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:30] {2392} INFO -  at 26.0s,	estimator extra_tree's best error=0.2118,	best estimator extra_tree's best error=0.2118
# [flaml.automl.logger: 09-27 14:48:30] {2219} INFO - iteration 124, current learner rf
# [flaml.automl.logger: 09-27 14:48:30] {2392} INFO -  at 26.4s,	estimator rf's best error=0.2202,	best estimator extra_tree's best error=0.2118
# [flaml.automl.logger: 09-27 14:48:30] {2219} INFO - iteration 125, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:33] {2392} INFO -  at 29.0s,	estimator lgbm's best error=0.2136,	best estimator extra_tree's best error=0.2118
# [flaml.automl.logger: 09-27 14:48:33] {2219} INFO - iteration 126, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:33] {2392} INFO -  at 29.3s,	estimator lgbm's best error=0.2136,	best estimator extra_tree's best error=0.2118
# [flaml.automl.logger: 09-27 14:48:33] {2219} INFO - iteration 127, current learner lgbm
# [flaml.automl.logger: 09-27 14:48:36] {2392} INFO -  at 32.1s,	estimator lgbm's best error=0.2131,	best estimator extra_tree's best error=0.2118
# [flaml.automl.logger: 09-27 14:48:36] {2219} INFO - iteration 128, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:36] {2392} INFO -  at 32.2s,	estimator xgboost's best error=0.2309,	best estimator extra_tree's best error=0.2118
# [flaml.automl.logger: 09-27 14:48:36] {2219} INFO - iteration 129, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:36] {2392} INFO -  at 32.4s,	estimator extra_tree's best error=0.2105,	best estimator extra_tree's best error=0.2105
# [flaml.automl.logger: 09-27 14:48:36] {2219} INFO - iteration 130, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:36] {2392} INFO -  at 32.4s,	estimator xgboost's best error=0.2309,	best estimator extra_tree's best error=0.2105
# [flaml.automl.logger: 09-27 14:48:36] {2219} INFO - iteration 131, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:37] {2392} INFO -  at 32.6s,	estimator xgboost's best error=0.2229,	best estimator extra_tree's best error=0.2105
# [flaml.automl.logger: 09-27 14:48:37] {2219} INFO - iteration 132, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:37] {2392} INFO -  at 32.8s,	estimator extra_tree's best error=0.2105,	best estimator extra_tree's best error=0.2105
# [flaml.automl.logger: 09-27 14:48:37] {2219} INFO - iteration 133, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:37] {2392} INFO -  at 32.9s,	estimator xgboost's best error=0.2229,	best estimator extra_tree's best error=0.2105
# [flaml.automl.logger: 09-27 14:48:37] {2219} INFO - iteration 134, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:37] {2392} INFO -  at 33.3s,	estimator xgboost's best error=0.2229,	best estimator extra_tree's best error=0.2105
# [flaml.automl.logger: 09-27 14:48:37] {2219} INFO - iteration 135, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:38] {2392} INFO -  at 33.5s,	estimator extra_tree's best error=0.2105,	best estimator extra_tree's best error=0.2105
# [flaml.automl.logger: 09-27 14:48:38] {2219} INFO - iteration 136, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:38] {2392} INFO -  at 33.8s,	estimator extra_tree's best error=0.2105,	best estimator extra_tree's best error=0.2105
# [flaml.automl.logger: 09-27 14:48:38] {2219} INFO - iteration 137, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:38] {2392} INFO -  at 34.0s,	estimator extra_tree's best error=0.2105,	best estimator extra_tree's best error=0.2105
# [flaml.automl.logger: 09-27 14:48:38] {2219} INFO - iteration 138, current learner rf
# [flaml.automl.logger: 09-27 14:48:39] {2392} INFO -  at 34.9s,	estimator rf's best error=0.2202,	best estimator extra_tree's best error=0.2105
# [flaml.automl.logger: 09-27 14:48:39] {2219} INFO - iteration 139, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:39] {2392} INFO -  at 35.2s,	estimator extra_tree's best error=0.2105,	best estimator extra_tree's best error=0.2105
# [flaml.automl.logger: 09-27 14:48:39] {2219} INFO - iteration 140, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:39] {2392} INFO -  at 35.4s,	estimator xgboost's best error=0.2229,	best estimator extra_tree's best error=0.2105
# [flaml.automl.logger: 09-27 14:48:39] {2219} INFO - iteration 141, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:40] {2392} INFO -  at 35.7s,	estimator extra_tree's best error=0.2105,	best estimator extra_tree's best error=0.2105
# [flaml.automl.logger: 09-27 14:48:40] {2219} INFO - iteration 142, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:40] {2392} INFO -  at 35.9s,	estimator xgboost's best error=0.2229,	best estimator extra_tree's best error=0.2105
# [flaml.automl.logger: 09-27 14:48:40] {2219} INFO - iteration 143, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:40] {2392} INFO -  at 36.1s,	estimator extra_tree's best error=0.2105,	best estimator extra_tree's best error=0.2105
# [flaml.automl.logger: 09-27 14:48:40] {2219} INFO - iteration 144, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:40] {2392} INFO -  at 36.3s,	estimator extra_tree's best error=0.2105,	best estimator extra_tree's best error=0.2105
# [flaml.automl.logger: 09-27 14:48:40] {2219} INFO - iteration 145, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:41] {2392} INFO -  at 36.5s,	estimator extra_tree's best error=0.2105,	best estimator extra_tree's best error=0.2105
# [flaml.automl.logger: 09-27 14:48:41] {2219} INFO - iteration 146, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:41] {2392} INFO -  at 36.7s,	estimator xgboost's best error=0.2229,	best estimator extra_tree's best error=0.2105
# [flaml.automl.logger: 09-27 14:48:41] {2219} INFO - iteration 147, current learner rf
# [flaml.automl.logger: 09-27 14:48:41] {2392} INFO -  at 37.1s,	estimator rf's best error=0.2202,	best estimator extra_tree's best error=0.2105
# [flaml.automl.logger: 09-27 14:48:41] {2219} INFO - iteration 148, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:41] {2392} INFO -  at 37.3s,	estimator xgboost's best error=0.2145,	best estimator extra_tree's best error=0.2105
# [flaml.automl.logger: 09-27 14:48:41] {2219} INFO - iteration 149, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:41] {2392} INFO -  at 37.3s,	estimator xgboost's best error=0.2145,	best estimator extra_tree's best error=0.2105
# [flaml.automl.logger: 09-27 14:48:41] {2219} INFO - iteration 150, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:42] {2392} INFO -  at 37.6s,	estimator xgboost's best error=0.2145,	best estimator extra_tree's best error=0.2105
# [flaml.automl.logger: 09-27 14:48:42] {2219} INFO - iteration 151, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:42] {2392} INFO -  at 37.7s,	estimator xgboost's best error=0.2145,	best estimator extra_tree's best error=0.2105
# [flaml.automl.logger: 09-27 14:48:42] {2219} INFO - iteration 152, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:42] {2392} INFO -  at 37.9s,	estimator extra_tree's best error=0.2083,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:42] {2219} INFO - iteration 153, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:42] {2392} INFO -  at 38.1s,	estimator extra_tree's best error=0.2083,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:42] {2219} INFO - iteration 154, current learner rf
# [flaml.automl.logger: 09-27 14:48:43] {2392} INFO -  at 38.7s,	estimator rf's best error=0.2202,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:43] {2219} INFO - iteration 155, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:43] {2392} INFO -  at 38.8s,	estimator xgboost's best error=0.2145,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:43] {2219} INFO - iteration 156, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:43] {2392} INFO -  at 39.2s,	estimator extra_tree's best error=0.2083,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:43] {2219} INFO - iteration 157, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:43] {2392} INFO -  at 39.4s,	estimator extra_tree's best error=0.2083,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:43] {2219} INFO - iteration 158, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:44] {2392} INFO -  at 39.5s,	estimator xgboost's best error=0.2145,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:44] {2219} INFO - iteration 159, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:44] {2392} INFO -  at 39.9s,	estimator xgboost's best error=0.2136,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:44] {2219} INFO - iteration 160, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:44] {2392} INFO -  at 40.3s,	estimator extra_tree's best error=0.2083,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:44] {2219} INFO - iteration 161, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:45] {2392} INFO -  at 40.6s,	estimator xgboost's best error=0.2136,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:45] {2219} INFO - iteration 162, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:45] {2392} INFO -  at 40.8s,	estimator extra_tree's best error=0.2083,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:45] {2219} INFO - iteration 163, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:45] {2392} INFO -  at 41.1s,	estimator extra_tree's best error=0.2083,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:45] {2219} INFO - iteration 164, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:45] {2392} INFO -  at 41.4s,	estimator extra_tree's best error=0.2083,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:45] {2219} INFO - iteration 165, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:46] {2392} INFO -  at 41.6s,	estimator extra_tree's best error=0.2083,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:46] {2219} INFO - iteration 166, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:46] {2392} INFO -  at 41.9s,	estimator extra_tree's best error=0.2083,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:46] {2219} INFO - iteration 167, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:46] {2392} INFO -  at 42.2s,	estimator extra_tree's best error=0.2083,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:46] {2219} INFO - iteration 168, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:47] {2392} INFO -  at 42.5s,	estimator extra_tree's best error=0.2083,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:47] {2219} INFO - iteration 169, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:47] {2392} INFO -  at 42.8s,	estimator xgboost's best error=0.2136,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:47] {2219} INFO - iteration 170, current learner rf
# [flaml.automl.logger: 09-27 14:48:47] {2392} INFO -  at 43.3s,	estimator rf's best error=0.2158,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:47] {2219} INFO - iteration 171, current learner rf
# [flaml.automl.logger: 09-27 14:48:48] {2392} INFO -  at 43.9s,	estimator rf's best error=0.2158,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:48] {2219} INFO - iteration 172, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:48] {2392} INFO -  at 44.3s,	estimator extra_tree's best error=0.2083,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:48] {2219} INFO - iteration 173, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:49] {2392} INFO -  at 44.5s,	estimator extra_tree's best error=0.2083,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:49] {2219} INFO - iteration 174, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:49] {2392} INFO -  at 44.9s,	estimator extra_tree's best error=0.2083,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:49] {2219} INFO - iteration 175, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:49] {2392} INFO -  at 45.2s,	estimator xgboost's best error=0.2136,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:49] {2219} INFO - iteration 176, current learner xgb_limitdepth
# [flaml.automl.logger: 09-27 14:48:49] {2392} INFO -  at 45.3s,	estimator xgb_limitdepth's best error=0.2322,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:49] {2219} INFO - iteration 177, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:50] {2392} INFO -  at 45.6s,	estimator extra_tree's best error=0.2083,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:50] {2219} INFO - iteration 178, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:50] {2392} INFO -  at 45.8s,	estimator extra_tree's best error=0.2083,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:50] {2219} INFO - iteration 179, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:50] {2392} INFO -  at 46.2s,	estimator extra_tree's best error=0.2083,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:50] {2219} INFO - iteration 180, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:50] {2392} INFO -  at 46.5s,	estimator extra_tree's best error=0.2083,	best estimator extra_tree's best error=0.2083
# [flaml.automl.logger: 09-27 14:48:50] {2219} INFO - iteration 181, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:51] {2392} INFO -  at 46.8s,	estimator extra_tree's best error=0.2056,	best estimator extra_tree's best error=0.2056
# [flaml.automl.logger: 09-27 14:48:51] {2219} INFO - iteration 182, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:51] {2392} INFO -  at 47.2s,	estimator xgboost's best error=0.2136,	best estimator extra_tree's best error=0.2056
# [flaml.automl.logger: 09-27 14:48:51] {2219} INFO - iteration 183, current learner rf
# [flaml.automl.logger: 09-27 14:48:52] {2392} INFO -  at 47.6s,	estimator rf's best error=0.2158,	best estimator extra_tree's best error=0.2056
# [flaml.automl.logger: 09-27 14:48:52] {2219} INFO - iteration 184, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:52] {2392} INFO -  at 47.8s,	estimator extra_tree's best error=0.2056,	best estimator extra_tree's best error=0.2056
# [flaml.automl.logger: 09-27 14:48:52] {2219} INFO - iteration 185, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:52] {2392} INFO -  at 48.3s,	estimator extra_tree's best error=0.2056,	best estimator extra_tree's best error=0.2056
# [flaml.automl.logger: 09-27 14:48:52] {2219} INFO - iteration 186, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:53] {2392} INFO -  at 49.1s,	estimator xgboost's best error=0.2136,	best estimator extra_tree's best error=0.2056
# [flaml.automl.logger: 09-27 14:48:53] {2219} INFO - iteration 187, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:53] {2392} INFO -  at 49.3s,	estimator extra_tree's best error=0.2056,	best estimator extra_tree's best error=0.2056
# [flaml.automl.logger: 09-27 14:48:53] {2219} INFO - iteration 188, current learner rf
# [flaml.automl.logger: 09-27 14:48:54] {2392} INFO -  at 49.9s,	estimator rf's best error=0.2158,	best estimator extra_tree's best error=0.2056
# [flaml.automl.logger: 09-27 14:48:54] {2219} INFO - iteration 189, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:54] {2392} INFO -  at 50.3s,	estimator extra_tree's best error=0.2056,	best estimator extra_tree's best error=0.2056
# [flaml.automl.logger: 09-27 14:48:54] {2219} INFO - iteration 190, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:55] {2392} INFO -  at 50.5s,	estimator extra_tree's best error=0.2056,	best estimator extra_tree's best error=0.2056
# [flaml.automl.logger: 09-27 14:48:55] {2219} INFO - iteration 191, current learner xgboost
# [flaml.automl.logger: 09-27 14:48:55] {2392} INFO -  at 50.7s,	estimator xgboost's best error=0.2136,	best estimator extra_tree's best error=0.2056
# [flaml.automl.logger: 09-27 14:48:55] {2219} INFO - iteration 192, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:55] {2392} INFO -  at 51.1s,	estimator extra_tree's best error=0.2056,	best estimator extra_tree's best error=0.2056
# [flaml.automl.logger: 09-27 14:48:55] {2219} INFO - iteration 193, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:55] {2392} INFO -  at 51.4s,	estimator extra_tree's best error=0.2056,	best estimator extra_tree's best error=0.2056
# [flaml.automl.logger: 09-27 14:48:55] {2219} INFO - iteration 194, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:56] {2392} INFO -  at 51.7s,	estimator extra_tree's best error=0.2056,	best estimator extra_tree's best error=0.2056
# [flaml.automl.logger: 09-27 14:48:56] {2219} INFO - iteration 195, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:56] {2392} INFO -  at 52.0s,	estimator extra_tree's best error=0.2056,	best estimator extra_tree's best error=0.2056
# [flaml.automl.logger: 09-27 14:48:56] {2219} INFO - iteration 196, current learner rf
# [flaml.automl.logger: 09-27 14:48:56] {2392} INFO -  at 52.4s,	estimator rf's best error=0.2109,	best estimator extra_tree's best error=0.2056
# [flaml.automl.logger: 09-27 14:48:56] {2219} INFO - iteration 197, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:57] {2392} INFO -  at 52.9s,	estimator extra_tree's best error=0.2056,	best estimator extra_tree's best error=0.2056
# [flaml.automl.logger: 09-27 14:48:57] {2219} INFO - iteration 198, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:57] {2392} INFO -  at 53.4s,	estimator extra_tree's best error=0.2056,	best estimator extra_tree's best error=0.2056
# [flaml.automl.logger: 09-27 14:48:57] {2219} INFO - iteration 199, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:58] {2392} INFO -  at 53.6s,	estimator extra_tree's best error=0.2056,	best estimator extra_tree's best error=0.2056
# [flaml.automl.logger: 09-27 14:48:58] {2219} INFO - iteration 200, current learner extra_tree
# [flaml.automl.logger: 09-27 14:48:58] {2392} INFO -  at 53.9s,	estimator extra_tree's best error=0.2056,	best estimator extra_tree's best error=0.2056
# [flaml.automl.logger: 09-27 14:48:58] {2219} INFO - iteration 201, current learner rf
# [flaml.automl.logger: 09-27 14:48:59] {2392} INFO -  at 54.6s,	estimator rf's best error=0.2109,	best estimator extra_tree's best error=0.2056
# [flaml.automl.logger: 09-27 14:48:59] {2219} INFO - iteration 202, current learner rf
# ...
# [flaml.automl.logger: 09-27 14:53:26] {2219} INFO - iteration 515, current learner xgboost
# [flaml.automl.logger: 09-27 14:53:27] {2392} INFO -  at 322.5s,	estimator xgboost's best error=0.2096,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:27] {2219} INFO - iteration 516, current learner extra_tree
# [flaml.automl.logger: 09-27 14:53:27] {2392} INFO -  at 322.9s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:27] {2219} INFO - iteration 517, current learner extra_tree
# [flaml.automl.logger: 09-27 14:53:27] {2392} INFO -  at 323.1s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:27] {2219} INFO - iteration 518, current learner rf
# [flaml.automl.logger: 09-27 14:53:28] {2392} INFO -  at 324.1s,	estimator rf's best error=0.2078,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:28] {2219} INFO - iteration 519, current learner xgboost
# [flaml.automl.logger: 09-27 14:53:29] {2392} INFO -  at 324.8s,	estimator xgboost's best error=0.2096,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:29] {2219} INFO - iteration 520, current learner extra_tree
# [flaml.automl.logger: 09-27 14:53:29] {2392} INFO -  at 325.2s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:29] {2219} INFO - iteration 521, current learner extra_tree
# [flaml.automl.logger: 09-27 14:53:30] {2392} INFO -  at 325.6s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:30] {2219} INFO - iteration 522, current learner extra_tree
# [flaml.automl.logger: 09-27 14:53:30] {2392} INFO -  at 325.8s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:30] {2219} INFO - iteration 523, current learner rf
# [flaml.automl.logger: 09-27 14:53:31] {2392} INFO -  at 327.0s,	estimator rf's best error=0.2078,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:31] {2219} INFO - iteration 524, current learner extra_tree
# [flaml.automl.logger: 09-27 14:53:31] {2392} INFO -  at 327.3s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:31] {2219} INFO - iteration 525, current learner lrl1
# [flaml.automl.logger: 09-27 14:53:32] {2392} INFO -  at 327.7s,	estimator lrl1's best error=0.3632,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:32] {2219} INFO - iteration 526, current learner extra_tree
# [flaml.automl.logger: 09-27 14:53:32] {2392} INFO -  at 328.1s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:32] {2219} INFO - iteration 527, current learner extra_tree
# [flaml.automl.logger: 09-27 14:53:32] {2392} INFO -  at 328.3s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:32] {2219} INFO - iteration 528, current learner lrl1
# [flaml.automl.logger: 09-27 14:53:33] {2392} INFO -  at 328.7s,	estimator lrl1's best error=0.3632,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:33] {2219} INFO - iteration 529, current learner xgb_limitdepth
# [flaml.automl.logger: 09-27 14:53:35] {2392} INFO -  at 330.7s,	estimator xgb_limitdepth's best error=0.2056,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:35] {2219} INFO - iteration 530, current learner extra_tree
# [flaml.automl.logger: 09-27 14:53:35] {2392} INFO -  at 331.0s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:35] {2219} INFO - iteration 531, current learner rf
# [flaml.automl.logger: 09-27 14:53:35] {2392} INFO -  at 331.3s,	estimator rf's best error=0.2078,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:35] {2219} INFO - iteration 532, current learner rf
# [flaml.automl.logger: 09-27 14:53:36] {2392} INFO -  at 331.7s,	estimator rf's best error=0.2078,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:36] {2219} INFO - iteration 533, current learner rf
# [flaml.automl.logger: 09-27 14:53:37] {2392} INFO -  at 332.6s,	estimator rf's best error=0.2078,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:37] {2219} INFO - iteration 534, current learner extra_tree
# [flaml.automl.logger: 09-27 14:53:37] {2392} INFO -  at 332.9s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:37] {2219} INFO - iteration 535, current learner extra_tree
# [flaml.automl.logger: 09-27 14:53:37] {2392} INFO -  at 333.2s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:37] {2219} INFO - iteration 536, current learner lrl1
# [flaml.automl.logger: 09-27 14:53:38] {2392} INFO -  at 333.6s,	estimator lrl1's best error=0.3632,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:38] {2219} INFO - iteration 537, current learner rf
# [flaml.automl.logger: 09-27 14:53:38] {2392} INFO -  at 334.5s,	estimator rf's best error=0.2078,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:38] {2219} INFO - iteration 538, current learner lrl1
# [flaml.automl.logger: 09-27 14:53:39] {2392} INFO -  at 334.8s,	estimator lrl1's best error=0.3632,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:39] {2219} INFO - iteration 539, current learner extra_tree
# [flaml.automl.logger: 09-27 14:53:39] {2392} INFO -  at 335.2s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:39] {2219} INFO - iteration 540, current learner extra_tree
# [flaml.automl.logger: 09-27 14:53:39] {2392} INFO -  at 335.5s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:39] {2219} INFO - iteration 541, current learner extra_tree
# [flaml.automl.logger: 09-27 14:53:40] {2392} INFO -  at 335.7s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:40] {2219} INFO - iteration 542, current learner extra_tree
# [flaml.automl.logger: 09-27 14:53:40] {2392} INFO -  at 336.1s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:40] {2219} INFO - iteration 543, current learner extra_tree
# [flaml.automl.logger: 09-27 14:53:40] {2392} INFO -  at 336.3s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:40] {2219} INFO - iteration 544, current learner lgbm
# [flaml.automl.logger: 09-27 14:53:42] {2392} INFO -  at 337.5s,	estimator lgbm's best error=0.2078,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:42] {2219} INFO - iteration 545, current learner lgbm
# [flaml.automl.logger: 09-27 14:53:43] {2392} INFO -  at 338.9s,	estimator lgbm's best error=0.2078,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:43] {2219} INFO - iteration 546, current learner xgboost
# [flaml.automl.logger: 09-27 14:53:43] {2392} INFO -  at 339.5s,	estimator xgboost's best error=0.2096,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:43] {2219} INFO - iteration 547, current learner extra_tree
# [flaml.automl.logger: 09-27 14:53:44] {2392} INFO -  at 339.8s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:44] {2219} INFO - iteration 548, current learner xgboost
# [flaml.automl.logger: 09-27 14:53:44] {2392} INFO -  at 340.2s,	estimator xgboost's best error=0.2096,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:44] {2219} INFO - iteration 549, current learner xgboost
# [flaml.automl.logger: 09-27 14:53:45] {2392} INFO -  at 341.1s,	estimator xgboost's best error=0.2096,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:45] {2219} INFO - iteration 550, current learner lgbm
# [flaml.automl.logger: 09-27 14:53:46] {2392} INFO -  at 342.3s,	estimator lgbm's best error=0.2078,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:46] {2219} INFO - iteration 551, current learner lgbm
# [flaml.automl.logger: 09-27 14:53:50] {2392} INFO -  at 345.7s,	estimator lgbm's best error=0.2078,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:50] {2219} INFO - iteration 552, current learner extra_tree
# [flaml.automl.logger: 09-27 14:53:50] {2392} INFO -  at 346.0s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:50] {2219} INFO - iteration 553, current learner rf
# [flaml.automl.logger: 09-27 14:53:50] {2392} INFO -  at 346.4s,	estimator rf's best error=0.2078,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:50] {2219} INFO - iteration 554, current learner lrl1
# [flaml.automl.logger: 09-27 14:53:51] {2392} INFO -  at 346.8s,	estimator lrl1's best error=0.3632,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:51] {2219} INFO - iteration 555, current learner lgbm
# [flaml.automl.logger: 09-27 14:53:52] {2392} INFO -  at 347.7s,	estimator lgbm's best error=0.2078,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:52] {2219} INFO - iteration 556, current learner rf
# [flaml.automl.logger: 09-27 14:53:52] {2392} INFO -  at 348.4s,	estimator rf's best error=0.2078,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:52] {2219} INFO - iteration 557, current learner extra_tree
# [flaml.automl.logger: 09-27 14:53:53] {2392} INFO -  at 348.6s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:53] {2219} INFO - iteration 558, current learner extra_tree
# [flaml.automl.logger: 09-27 14:53:53] {2392} INFO -  at 348.9s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:53] {2219} INFO - iteration 559, current learner xgboost
# [flaml.automl.logger: 09-27 14:53:54] {2392} INFO -  at 349.9s,	estimator xgboost's best error=0.2096,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:54] {2219} INFO - iteration 560, current learner lgbm
# [flaml.automl.logger: 09-27 14:53:56] {2392} INFO -  at 351.9s,	estimator lgbm's best error=0.2078,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:56] {2219} INFO - iteration 561, current learner rf
# [flaml.automl.logger: 09-27 14:53:56] {2392} INFO -  at 352.4s,	estimator rf's best error=0.2078,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:56] {2219} INFO - iteration 562, current learner extra_tree
# [flaml.automl.logger: 09-27 14:53:57] {2392} INFO -  at 352.8s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:57] {2219} INFO - iteration 563, current learner extra_tree
# [flaml.automl.logger: 09-27 14:53:57] {2392} INFO -  at 353.1s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:57] {2219} INFO - iteration 564, current learner extra_tree
# [flaml.automl.logger: 09-27 14:53:57] {2392} INFO -  at 353.4s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:57] {2219} INFO - iteration 565, current learner lgbm
# [flaml.automl.logger: 09-27 14:53:58] {2392} INFO -  at 354.2s,	estimator lgbm's best error=0.2078,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:53:58] {2219} INFO - iteration 566, current learner lgbm
# [flaml.automl.logger: 09-27 14:54:00] {2392} INFO -  at 355.6s,	estimator lgbm's best error=0.2078,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:54:00] {2219} INFO - iteration 567, current learner extra_tree
# [flaml.automl.logger: 09-27 14:54:00] {2392} INFO -  at 356.0s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:54:00] {2219} INFO - iteration 568, current learner extra_tree
# [flaml.automl.logger: 09-27 14:54:00] {2392} INFO -  at 356.2s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:54:00] {2219} INFO - iteration 569, current learner lgbm
# [flaml.automl.logger: 09-27 14:54:02] {2392} INFO -  at 357.5s,	estimator lgbm's best error=0.2078,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:54:02] {2219} INFO - iteration 570, current learner extra_tree
# [flaml.automl.logger: 09-27 14:54:02] {2392} INFO -  at 357.8s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:54:02] {2219} INFO - iteration 571, current learner extra_tree
# [flaml.automl.logger: 09-27 14:54:02] {2392} INFO -  at 358.0s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:54:02] {2219} INFO - iteration 572, current learner xgboost
# [flaml.automl.logger: 09-27 14:54:02] {2392} INFO -  at 358.3s,	estimator xgboost's best error=0.2096,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:54:02] {2219} INFO - iteration 573, current learner extra_tree
# [flaml.automl.logger: 09-27 14:54:03] {2392} INFO -  at 358.5s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:54:03] {2219} INFO - iteration 574, current learner extra_tree
# [flaml.automl.logger: 09-27 14:54:03] {2392} INFO -  at 358.9s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:54:03] {2219} INFO - iteration 575, current learner rf
# [flaml.automl.logger: 09-27 14:54:04] {2392} INFO -  at 359.7s,	estimator rf's best error=0.2078,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:54:04] {2219} INFO - iteration 576, current learner extra_tree
# [flaml.automl.logger: 09-27 14:54:04] {2392} INFO -  at 359.9s,	estimator extra_tree's best error=0.2020,	best estimator extra_tree's best error=0.2020
# [flaml.automl.logger: 09-27 14:54:04] {2628} INFO - retrain extra_tree for 0.1s
# [flaml.automl.logger: 09-27 14:54:04] {2631} INFO - retrained model: ExtraTreesClassifier(criterion='entropy', max_features=0.8732931401605519,
#                      max_leaf_nodes=299, n_estimators=43, n_jobs=-1,
#                      random_state=12032022)
# [flaml.automl.logger: 09-27 14:54:04] {1931} INFO - fit succeeded
# [flaml.automl.logger: 09-27 14:54:04] {1932} INFO - Time taken to find the best model: 176.51097202301025
# Estimator: extra_tree
# Config: {'n_estimators': 43, 'max_features': 0.8732931401605519, 'max_leaves': 299, 'criterion': 'entropy'}
# Test Accuracy: 0.817
# Classification:               precision    recall  f1-score   support
#
#            0       0.84      0.79      0.81       282
#            1       0.80      0.84      0.82       282
#
#     accuracy                           0.82       564
#    macro avg       0.82      0.82      0.82       564
# weighted avg       0.82      0.82      0.82       564

# %% [markdown]
# ## Process Example Video to test for OKD Predictions
#
# ### Creates overall function for processing and predicting
#
# - Load Pose, PHC, and Classifier models
# - Process video in frame batches for quicker processing
# - Predict OKD for a given frame (futue iterations need to identify where pitch starts)
# - Save video with predictions (if given an output path)
# - Print percentage of frames for video predicted as OKD

# %%
import numpy as np
from tqdm import tqdm
from scripts.load_tools import load_model
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore", message=r".*X does not have valid feature names.*")


# create function to process individual video for OKD given models
def process_okd_video(video_path, pose_model, phc_model, model, output_path=None, batch_size=4) -> list[int]:
    cap = cv2.VideoCapture(video_path)
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    
    if output_path: # save video with predictions if output path is specified
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
    
    okd_predictions = []
    frames = []
    
    for _ in tqdm(range(0, total_frames, batch_size), desc="Processing batches"): # process video in batches of frames for quicker processing
        batch_frames = []
        for _ in range(batch_size):
            ret, frame = cap.read()
            if not ret:
                break
            batch_frames.append(frame)
        
        if not batch_frames:
            break
        
        # perform detections on batch
        phc_results = phc_model(batch_frames, device='mps', verbose=False)
        
        for i, frame in enumerate(batch_frames):
            catcher_box = None
            for box in phc_results[i].boxes:
                cls = int(box.cls)
                if cls == 2:
                    catcher_box = box.xyxy[0].cpu().numpy() # extract catcher box coordinates
                    break
            
            if catcher_box is None:
                okd_predictions.append(0)
                frames.append(frame)
                continue
            
             # predict pose within catcher's box
            x1, y1, x2, y2 = map(int, catcher_box)
            catcher_frame = frame[y1:y2, x1:x2]
            pose_results = pose_model(catcher_frame, device='mps', verbose=False, conf=0.5)[0] 
            
            pose_points = []
            for keypoints in pose_results.keypoints:
                for point in keypoints.xyn[0].cpu().numpy():
                    pose_points.extend(point)


            # pad pose points for expected length
            pose_points = pose_points[:34] + [0] * (34 - len(pose_points))
            
            okd_pred = model.predict(np.array(pose_points).reshape(1, -1))[0] # predict with classifier model
            okd_predictions.append(okd_pred)
            
            if output_path:
                cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 0), 2)
                cv2.putText(frame, "Catcher", (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 1)
                cv2.putText(frame, f"OKD: {'Yes' if okd_pred == 1 else 'No'}", (10, 30),
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0) if okd_pred == 1 else (0, 0, 255), 2)
            
            frames.append(frame)
    
    if output_path:
        for frame in frames:
            out.write(frame)
    
    cap.release()
    if output_path:
        out.release()
    
    return okd_predictions


pose_model = YOLO("yolov8l-pose.pt")
phc_model = YOLO(load_model("phc_detector"))

video_path = "assets/example_broadcast_video.mp4"
output_path = "test_okd.mp4"

okd_predictions = process_okd_video(video_path, pose_model, phc_model, model, output_path, batch_size=4)

okd_count = sum(okd_predictions)
total_frames = len(okd_predictions)

print(f"Predicted OKD in {okd_count/total_frames:.1%} of {total_frames} frames.")
# Out:
# Model found at models/pitcher_hitter_catcher_detector/model_weights/pitcher_hitter_catcher_detector_v3.pt
# Processing batches:   0%|          | 0/98 [00:00<?, ?it/s]
# WARNING ⚠️ Apple MPS known Pose bug. Recommend 'device=cpu' for Pose models. See https://github.com/ultralytics/ultralytics/issues/4031.
# Processing batches: 100%|██████████| 98/98 [00:52<00:00,  1.85it/s]
# Predicted OKD in 71.7% of 392 frames.

# %% [markdown]
# ##**CONGRATS!** You utilized the OKD / NOKD datase and pose estimation to train a classifier to predict if a catcher is in a one-knee down position!
#
# ### The classifier model and it's relavent information can be found in the models/okd_nokd_classifier folder.
